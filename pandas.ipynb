# %%
import pandas as pd
df = pd.read_csv("PremierLeagueMatches.csv")
df
# Out:
#       Matchday        Date   Time        Home Team  homeScore  homeXG  \
# 0            1  2022-08-05  20:00   Crystal Palace        0.0     1.2
# 1            1  2022-08-06  12:30           Fulham        2.0     1.2
# 2            1  2022-08-06  15:00        Tottenham        4.0     1.5
# 3            1  2022-08-06  15:00    Newcastle Utd        2.0     1.7
# 4            1  2022-08-06  15:00     Leeds United        2.0     0.8
# ...        ...         ...    ...              ...        ...     ...
# 1135        38  2025-05-25  16:00           Fulham        NaN     NaN
# 1136        38  2025-05-25  16:00  Nott'ham Forest        NaN     NaN
# 1137        38  2025-05-25  16:00   Manchester Utd        NaN     NaN
# 1138        38  2025-05-25  16:00           Wolves        NaN     NaN
# 1139        38  2025-05-25  16:00        Tottenham        NaN     NaN
#
#       awayScore  awayXG        Away Team Attendance         Referee  \
# ...

# %%
#find the sha[e of dataframe
df.shape
# Out:
# (1140, 14)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Matchday        Date   Time        Home Team  homeScore  homeXG  \
# 0            1  2022-08-05  20:00   Crystal Palace        0.0     1.2
# 1            1  2022-08-06  12:30           Fulham        2.0     1.2
# 2            1  2022-08-06  15:00        Tottenham        4.0     1.5
# 3            1  2022-08-06  15:00    Newcastle Utd        2.0     1.7
# 4            1  2022-08-06  15:00     Leeds United        2.0     0.8
# ...        ...         ...    ...              ...        ...     ...
# 1135        38  2025-05-25  16:00           Fulham        NaN     NaN
# 1136        38  2025-05-25  16:00  Nott'ham Forest        NaN     NaN
# 1137        38  2025-05-25  16:00   Manchester Utd        NaN     NaN
# 1138        38  2025-05-25  16:00           Wolves        NaN     NaN
# 1139        38  2025-05-25  16:00        Tottenham        NaN     NaN
#
#       awayScore  awayXG        Away Team Attendance         Referee  \
# ...

# %%
df.describe()
# Out:
#           Matchday    homeScore       homeXG    awayScore       awayXG
# count  1140.000000  1049.000000  1049.000000  1049.000000  1049.000000
# mean     19.500000     1.660629     1.626787     1.383222     1.316206
# std      10.970669     1.364484     0.878962     1.237897     0.781492
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%      10.000000     1.000000     1.000000     0.000000     0.800000
# 50%      19.500000     1.000000     1.500000     1.000000     1.200000
# 75%      29.000000     2.000000     2.200000     2.000000     1.700000
# max      38.000000     9.000000     7.000000     8.000000     5.600000

# %%
df.isna().sum
# Out:
# <bound method DataFrame.sum of       Matchday   Date   Time  Home Team  homeScore  homeXG  awayScore  awayXG  \
# 0        False  False  False      False      False   False      False   False
# 1        False  False  False      False      False   False      False   False
# 2        False  False  False      False      False   False      False   False
# 3        False  False  False      False      False   False      False   False
# 4        False  False  False      False      False   False      False   False
# ...        ...    ...    ...        ...        ...     ...        ...     ...
# 1135     False  False  False      False       True    True       True    True
# 1136     False  False  False      False       True    True       True    True
# 1137     False  False  False      False       True    True       True    True
# 1138     False  False  False      False       True    True       True    True
# 1139     False  False  False      False       True    True       True    True
#
# ...

# %%
df.count()
# Out:
# Matchday             1140
# Date                 1140
# Time                 1140
# Home Team            1140
# homeScore            1049
# homeXG               1049
# awayScore            1049
# awayXG               1049
# Away Team            1140
# Attendance           1045
# Referee              1049
# Stadium              1140
# Result               1049
# *Additional Stats    1049
# dtype: int64
